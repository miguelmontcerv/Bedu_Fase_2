# %%
import pandas as pd

# %%
star_wars = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/star-wars-survey/StarWars.csv', encoding='ISO-8859-1')
star_wars
# Out:
#       RespondentID  ... Location (Census Region)
# 0              NaN  ...                 Response
# 1     3.292880e+09  ...           South Atlantic
# 2     3.292880e+09  ...       West South Central
# 3     3.292765e+09  ...       West North Central
# 4     3.292763e+09  ...       West North Central
# ...            ...  ...                      ...
# 1182  3.288389e+09  ...       East North Central
# 1183  3.288379e+09  ...                 Mountain
# 1184  3.288375e+09  ...          Middle Atlantic
# 1185  3.288373e+09  ...       East North Central
# 1186  3.288373e+09  ...                  Pacific
#
# [1187 rows x 38 columns]

# %%
star_wars.shape
# Out:
# (1187, 38)

# %%
star_wars.isna().sum()
# Out:
# RespondentID                                                                                                                                       1
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                       0
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            350
# Which of the following Star Wars films have you seen? Please select all that apply.                                                              513
# Unnamed: 4                                                                                                                                       615
# Unnamed: 5                                                                                                                                       636
# ...

# %%
star_wars_dropped = star_wars.dropna(axis=0, how='any')
star_wars_dropped
# Out:
#       RespondentID  ... Location (Census Region)
# 5     3.292731e+09  ...       West North Central
# 6     3.292719e+09  ...          Middle Atlantic
# 16    3.292583e+09  ...       West South Central
# 23    3.292512e+09  ...           South Atlantic
# 27    3.292420e+09  ...           South Atlantic
# ...            ...  ...                      ...
# 1128  3.288485e+09  ...       West South Central
# 1129  3.288483e+09  ...          Middle Atlantic
# 1153  3.288429e+09  ...       East North Central
# 1172  3.288403e+09  ...                 Mountain
# 1176  3.288401e+09  ...       West South Central
#
# [132 rows x 38 columns]

# %%
star_wars_dropped.isna().sum()
# Out:
# RespondentID                                                                                                                                     0
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                     0
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            0
# Which of the following Star Wars films have you seen? Please select all that apply.                                                              0
# Unnamed: 4                                                                                                                                       0
# Unnamed: 5                                                                                                                                       0
# ...
